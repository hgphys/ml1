# %% [markdown]
# # **第４回 Python の基本（３）グラフの描画**

# %% [markdown]
# ## **問題１**
# Irisデータセットを読み込み、種類別で色分けした散布図として可視化することで、データの傾向を理解するプログラムを`ml1_04_01.py`として作成した。
# ３種類のあやめのうち他の種類と分類が容易と考えられる種類を１つ選択せよ。
#
# ＊データセットの説明：あやめの「花びら／がく片の長さと幅の4項目」＋「ラベル（3種類のあやめの分類）」

# %%
# ml1_04_01.py を実行する
# %run ml1_04_01.py

# %% [markdown]
# ## **問題２**
# Irisデータセットを読み込み相関行列を求めることで種類に限らず相関の強い特徴量同士を探索するためのプログラムを`ml1_04_02.py`として作成した。最も強い正の相関を持つ２つの特徴量を選択せよ。

# %%
# ml1_04_02.py を実行する
# %run ml1_04_02.py

# %% [markdown]
# ## **問題３**
# `data03.csv`のデータをフィットする直線を求めたい。データを読み込み、`mod04.py`モジュールで定義されている一次関数（直線）`function`を読み込み、パラメータを指定して、平均二乗誤差（MSE）と共に予測直線を描画するプログラムを`ml1_04_03.py`として作成した。平均二乗誤差を最小にする直線のパラメータを求めよ。ただし、直線のパラメータは整数とする。

# %%
# ml1_04_03.py を実行する
# %run ml1_04_03.py
