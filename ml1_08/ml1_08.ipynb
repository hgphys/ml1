# %% [markdown]
# # **第８回 回帰（１）単回帰と平均二乗誤差**

# %% [markdown]
# ## **問題１**
# サンプルデータ`data/data.csv`をCSV形式で読み込み、最初の70個を訓練データ`data/training_data.csv`、残りの30個をテストデータ`data/test_data.csv`として保存、また、`data/training_data.csv`を読み込み、訓練データの分散と共分散を計算するプログラムを`ml1_08_01.py`として作成した。このときの説明変数の分散と説明変数と目的変数の共分散を小数点以下第２位までの数値で求めよ。ただし、プログラムは誤りを含み、未完成である。

# %%
# ml1_08_01.py を実行する
# %run ml1_08_01.py

# %% [markdown]
# ## **問題２**
# 訓練データ`data/training_data.csv`を読み込み、勾配降下法を用いて単回帰のパラメータを推定、回帰直線付きの散布図を可視化するプログラムを`ml1_08_02.py`として作成した。このとき推定されたパラメータの値を小数点以下第２位までの数値で求めよ。ただし、プログラムは未完成である。必要に応じて、以下を参考にせよ。
# $$\hat{\boldsymbol{y}} = w_0\boldsymbol{1} + w_1 \boldsymbol{x}=\boldsymbol{\tilde{X}}\boldsymbol{w},~~~\boldsymbol{\tilde{X}}=\begin{pmatrix}
# 1 & x_{1}\\
# 1  & x_{2} \\
# \vdots & \vdots\\
# 1 & x_{n}
# \end{pmatrix},~~\boldsymbol{w}=\begin{pmatrix}
#  w_{0}\\
#  w_{1}
# \end{pmatrix}$$
# $$\nabla_{\boldsymbol{w}} E(\boldsymbol{w})=\begin{pmatrix}
# \frac{\partial}{\partial w_0}E(\boldsymbol{w})\\
# \frac{\partial}{\partial w_1}E(\boldsymbol{w})
# \end{pmatrix}
# =\begin{pmatrix}
# -\frac{2}{n}\sum_{i=1} ^n1\cdot\left(y_i -\hat{y}_i\right)\\
# -\frac{2}{n}\sum_{i=1} ^nx_i\left(y_i -\hat{y}_i\right)
# \end{pmatrix}=-\frac{2}{n}\boldsymbol{\tilde{X}}^\top(\boldsymbol{y} -\hat{\boldsymbol{y}} )$$

# %%
# ml1_08_02.py を実行する
# %run ml1_08_02.py

# %% [markdown]
# ## **問題３**
# 問題２で推定したパラメータを`model_param.csv`から用いて、訓練データとテストデータに予測値と残差の列を追加して、`prediction_training.csv`と`prediction_test.csv`として保存、残差プロットを可視化するプログラムを`ml1_08_03.py`として作成した。このとき、訓練データによって求められた回帰直線の決定係数を小数点以下第３位までの数値で答えよ。また、テストデータに対する残差の分散を小数点以下第３位までの数値で答えよ。ここで決定係数は、目的変数の分散に対する予測値の分散の割合として、以下のように定義される。
# $$R^2 = \frac{\mathrm{Var}[\hat{y}]}{\mathrm{Var}[y]}= \frac{\sigma_{\hat{y}} ^2}{\sigma_{y} ^2}$$

# %%
# ml1_08_03.py を実行する
# %run ml1_08_03.py
