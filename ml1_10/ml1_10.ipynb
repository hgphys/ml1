# %% [markdown]
# # **第１０回 回帰（３）非線形回帰**

# %% [markdown]
# ## **問題１**
# `ml1_09`において連立方程式を解析的に解くことで重回帰を行うクラスを`linearreg.py`として作成した。また、こちらを利用して、多項式回帰を行うクラスを`polyreg.py`として作成した。`data/data01.csv`のデータに対する多項式回帰を行うプログラムを`ml1_10_01.py`として作成した。偶数行を訓練データ、奇数行をテストデータとして、1次までの場合と9次までの多項式でフィットするプログラムを完成させ、それぞれの場合のテストデータに対する残差の二乗平均を求め、小数点第２位までの数値で求めよ。

# %%
# ml1_10_01.py を実行する
# %run ml1_10_01.py

# %% [markdown]
# ## **問題２**
# 問題１と同様に`data/data01.csv`のデータに対する多項式回帰を行うプログラムを`ml1_10_02.py`として作成した。全てのデータをテストデータとして、1次から9次の多項式でそれぞれフィットを行い、その重みのL2ノルムの二乗を計算するプログラムを完成させよ。また、$d=8$の場合のL2ノルムの値を小数点第３位までの数値で求めよ。

# %%
# ml1_10_02.py を実行する
# %run ml1_10_02.py

# %% [markdown]
# ## **問題３**
# `data/data03.csv`のデータに対する多項式でのリッジ回帰を行うプログラムを`ml1_10_03.py`として作成した。偶数行を訓練データ、奇数行をテストデータとして、9次までの多項式でフィットするプログラムとしている。ハイパーパラメータが$\alpha =0.01, 0.1, 1, 10$の場合のテストデータに対する残差の二乗平均を求め、最小となった残差の二乗平均の値を小数点第２位までの数値で求めよ。

# %%
# ml1_10_03.py を実行する
# %run ml1_10_03.py
