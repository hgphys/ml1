# %% [markdown]
# # **第９回 回帰（２）２次元線形回帰**

# %% [markdown]
# ## **問題１**
# 連立方程式を解析的に解くことで重回帰を行うクラスを`linearreg.py`として作成した。こちらを利用して、`data/data01.csv`のデータに対する２次元線形回帰を行うプログラムを`ml1_09_01.py`として作成した。`linearreg.py`を完成させ、回帰係数を求め、小数点第２位までの数値で求めよ。
#
# 必要に応じて、以下を参考にすること。重回帰モデルの損失関数の勾配は以下である。
# $$
# \nabla_{\boldsymbol{w}} E(\boldsymbol{w})= -2\tilde{X}^\top\boldsymbol{y}+2\tilde{X}^\top\boldsymbol{\tilde{X}w}
# $$
# この勾配に対して、$\nabla_{\boldsymbol{w}}E(\boldsymbol{w})=\boldsymbol{0}$となる  $\boldsymbol{w}$ を求めれば良い。したがって、次の連立方程式を解くことに等しい。
#
# $$\boldsymbol{\tilde{X}}^\top\boldsymbol{\tilde{X}w}=\boldsymbol{\tilde{X}}^\top\boldsymbol{y}$$

# %%
# ml1_09_01.py を実行する
# %run ml1_09_01.py

# %% [markdown]
# ## **問題２**
# 暴力犯罪件の発生数を貧困率と教育水準を用いて予測したい。2020年のアメリカの州別暴力事件発生回数のデータを以下のリンクから取得して`data`に保存した。
# https://www.statista.com/statistics/200445/reported-violent-crime-rate-in-the-us-states/
#
# はじめに、2020年のアメリカの州別貧困率と教育水準データを以下のサイトからCSVファイルとして取得して`data`に保存せよ。
# - 貧困率（貧困の定義については、ここでは詳細な説明は省略）
#
# https://data.census.gov/table?q=poverty+rate+by+state&tid=ACSST5Y2020.S1701
# - 教育水準（25歳以上で最終学歴が中学卒業未満）
#
# https://data.census.gov/table?q=education+attainment+by+state&tid=ACSST5Y2020.S1501
#
# 3つのデータセットを用いて重回帰分析を行うためのデータの前処理を行い、訓練データを`data/training_data.csv`として出力するプログラムを`ml1_09_02.py`として作成した。データの列名は州名（`State`）、10万人あたりの暴力事件発生件数（`Crime`）、州の貧困率（`Poverty`;%）25歳以上の中卒割合（`Less than 9th grade`;%）である。ここでは、すべてのデータを訓練データとした。また、データを３次元の散布図として可視化している。このとき`Crime`と`Poverty`の相関係数を小数点以下第３位までの数値で答えよ。
#
# ＊データセットの作成の際に必要なデータの前処理の参考にしてください。（Pandasでの表形式データの処理）

# %%
# ml1_09_02.py を実行する
# %run ml1_09_02.py

# %% [markdown]
# ## **問題３**
# 問題２で推定した訓練データを用いて、暴力犯罪件の発生数を貧困率と教育水準を用いて予測する重回帰モデルを作成するプログラムを`ml1_09_03.py`として作成した。このとき、訓練データによって求められた回帰直線の決定係数を小数点以下第３位までの数値で答えよ。また、このモデルを用いて貧困率に着目した予測の解釈を行うと次のようになる。「他の説明変数の値を固定した際に、貧困率が１%上昇すると、 10万人あたりの暴力犯罪の発生件数は〇〇件増加する」この〇〇に当てはまる数値を小数点以下第１位までの数値で答えよ。
#
# ただし、必要に応じて以下を参考にすること。重回帰モデルは以下である。
# $$\hat{y} = w_0+w_1x_1+w_2x_2$$

# %%
# ml1_09_03.py を実行する
# %run ml1_09_03.py
