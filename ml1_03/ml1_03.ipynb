# %% [markdown]
# # **第３回 Python の基本（２）関数、クラス**

# %% [markdown]
# ## **問題１**
# `mod03.py`モジュールの`function`関数を読み込み利用するプログラムを`ml1_03_01.py`として作成した。誤りを含むため、エラーを修正し、正しい出力結果を答えよ。

# %%
# ml1_03_01.py を実行する
# %run ml1_03_01.py

# %% [markdown]
# ## **問題２**
# 身長と体重、体脂肪率のサンプルデータ`data.csv`を読み込みBMIと肥満度(BMI)の列を追加して、`data02.csv`として出力するプログラムを`ml1_03_02.py`として作成した。肥満として判定されたサンプル数を答えよ。

# %%
# ml1_03_02.py を実行する
# %run ml1_03_02.py

# %% [markdown]
# ## **問題３**
# 問題２で出力された`data02.csv`を入力として、体脂肪率に基づいた肥満度(体脂肪率)の列を追加し、`data03.csv`として出力、肥満度(肥満度)と肥満度(体脂肪率)の一致率をBMIによる肥満度分類の正解率として出力するプログラムを`ml1_03_03.py`として作成した。出力された正解率を答えよ。

# %%
# ml1_03_03.py を実行する
# %run ml1_03_03.py
