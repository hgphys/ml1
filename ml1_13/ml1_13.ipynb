# %% [markdown]
# # **第１３回 分類（３）２次元入力２クラス分類**

# %% [markdown]
# ## **問題１**
# ２次元入力２クラス分類のためのデータ`data/data.csv`に対してロジスティック回帰を行うプログラムを`ml1_13_01.py`として作成した。プログラムを完成させ、推定されたパラメータの値を答えよ。ただし、小数点以下第２位までの数値で求めること。また、モデルによってClass 1と判別されたデータの個数を答えよ。

# %%
# ml1_13_01.py を実行する
# %run ml1_13_01.py

# %% [markdown]
# ## **問題２**
# ２次元入力２クラス分類のためのデータ`data/data.csv`に対して、偶数行を訓練データ、奇数行をテストデータとしてロジスティック回帰を行うプログラムを`ml1_13_02.py`としてプログラムを作成した。混同行列を計算し、正解率、適合率、再現率を、小数点以下第2位までの数値で求めること。

# %%
# ml1_13_02.py を実行する
# %run ml1_13_02.py
