# %% [markdown]
# # **第１５回 学習内容のまとめ**

# %% [markdown]
# ## **問題１**
# 「Boston Housing Dataset」を`data/boston_housing_dataset.csv`として保存した。このデータセットは、町ごとの住宅価格の中央値（MEDV）と、その町のさまざまな属性を表すデータをまとめたものである。住宅価格の中央値（MEDV）を目的変数として、その他のカラムの情報を説明変数としてリッジ回帰を行うプログラムを`ml1_15_01.py`として作成した。偶数行を訓練データ、奇数行をテストデータとして学習するプログラムを完成させ、最適なパラメータであるときのテストデータに対する決定係数の値を小数点以下第３位までの数値で答えよ。ただし、リッジ回帰のハイパーパラメータは、alpha= 1.0, 0.5, 0.1の中から最適なものを選ぶこと。また、このモデルを用いて人口1人当たりの犯罪発生数（CRIM）に着目した予測の解釈を行うと次のようになる。「他の説明変数の値を固定した際に、犯罪発生数が１回上昇すると、 町の住宅価格の中央値は〇〇ドル減少する」この〇〇に当てはまる数値を整数で数値で答えよ。ただし、MEDVの単位は1,000ドルである。

# %%
# ml1_15_01.py を実行する
# %run ml1_15_01.py

# %% [markdown]
# ## **問題２**
# 「Irisデータセット」を`data/iris_dataset.csv`として保存した。このデータセットは、アヤメの花の３つの品種（Setosa、Vericolor、Virginica）に関するデータセットです。それぞれの花のがく片と花弁の長さと幅の測定値が含まれています。品種（species）を目的変数、その他のカラムの情報を説明変数としてロジスティック回帰を行うプログラムを`ml1_15_02.py`として作成した。偶数行を訓練データ、奇数行をテストデータとして学習するプログラムを完成させ、最適なパラメータであるときのテストデータに対する正解率（%）とvirginicaの品種に着目したときの適合率（%）の値をを小数点以下第１位までの数値で答えよ。ただし、勾配法のハイパーパラメータである最大反復回数は10,000回とし、学習率は、 0.5, 0.1, 0.01の中から最適なものを選ぶこと。

# %%
# ml1_15_02.py を実行する
# %run ml1_15_02.py
