# %% [markdown]
# # **第７回 機械学習のための数学（３）確率・統計の基礎**

# %% [markdown]
# ## **問題１**
# `data01/*.csv`に2023年4月の金沢市と東京都の日別平均気温データを保存した。これを読み込み、月の平均気温と標準偏差、金沢と東京の気温の相関係数を求めるプログラムを`ml1_07_01.py`として作成した。金沢市の月平均気温および標準偏差、金沢と東京の気温の相関係数を求めよ。ただし、プログラムは未完成である。

# %%
# ml1_07_01.py を実行する
# %run ml1_07_01.py

# %% [markdown]
# ## **問題２**
# `data02/sample_data.csv`を読み込み、主成分分析を行うプログラムを`ml1_07_02.py`として作成した。元のデータの散布図と第１主成分と第２主成分に射影した散布図を可視化、第１主成分の寄与率を出力している。第２主成分の寄与率を出力させ、その値を答えよ。

# %%
# ml1_07_02.py を実行する
# %run ml1_07_02.py

# %% [markdown]
# ## **問題３**
# アーチェリーで10点を取る確率を推定する。アーチェリーを600射したところ、10点が48回出た。
# 10点を取る確率を最尤推定するプログラムを`ml1_07_03.py`として作成した。このとき、推定結果を答えよ。
#
# ただし、10点を取る確率 $\theta$ とすると、アーチェリーを$n$射して、10点が$k$回出る場合の尤度関数 $L(\theta)$は、二項分布の確率密度関数として、次のように定義できる。
# $$L(\theta)\propto \theta ^{k} (1-\theta)^{n-k}$$

# %%
# ml1_07_03.py を実行する
# %run ml1_07_03.py
