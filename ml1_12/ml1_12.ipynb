# %% [markdown]
# # **第１２回 分類（２）１次元入力２クラス分類と交差エントロピー誤差**

# %% [markdown]
# ## **問題１**
# １次元入力２クラス分類のためのデータ`data/data.csv`を散布図として可視化するプログラムを`ml1_12_01.py`として作成した。このデータから入力$x$に対して、$y=1$となる確率$P(y=1|x)$を求める。以下のそれぞれの区間での条件付き確率を求めよ。ただし、小数点以下第２位までの数値で求めること。
# - $P(y=1|x<0.9)$
# - $P(y=1|0.9\leq x\leq 1.2)$
# - $P(y=1|x>1.2)$

# %%
# ml1_12_01.py を実行する
# %run ml1_12_01.py

# %% [markdown]
# ## **問題２**
# １次元入力２クラス分類のためのデータ`data/data.csv`に対して平均交差エントロピー誤差を求めて可視化するプログラムを`ml1_12_02.py`として作成した。プログラムを完成させ、以下のパラメータに対する平均交差エントロピー誤差を求めよ。ただし、小数点以下第２位までの数値で求めること。
# $$w_0 = -10,~~w_1=9$$

# %%
# ml1_12_02.py を実行する
# %run ml1_12_02.py

# %% [markdown]
# ## **問題３**
# １次元入力２クラス分類のためのデータ`data/data.csv`に対してロジスティック回帰を行うプログラムを`ml1_12_03.py`として作成した。プログラムを完成させ、推定されたパラメータの値を答えよ。ただし、小数点以下第２位までの数値で求めること。
#
# ただし、必要に応じて、以下を参考にすること。
# シグモイド関数は以下である。
# $$\sigma(x)=\frac{1}{1+\exp(-x)}$$
#
# また、ロジスティック回帰の損失関数の勾配は以下で与えられる。
# $$\nabla_{\boldsymbol{w}} E(\boldsymbol{w})=\boldsymbol{\tilde{X}}^{\top}\left(\boldsymbol{\hat{y}}-\boldsymbol{y}\right)$$

# %%
# ml1_12_03.py を実行する
# %run ml1_12_03.py
