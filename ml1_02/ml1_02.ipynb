# %% [markdown]
# # **第２回 Python の基本（１）四則演算、if文、配列**

# %% [markdown]
# ## **問題１**
# 身長と体重データからBMIを計算するプログラムを`ml1_02_01.py`として作成した。誤りを含むため、エラーを修正し、正しい出力結果を答えよ。

# %%
# ml1_02_01.py を実行する
# %run ml1_02_01.py

# %% [markdown]
# ## **問題２**
# 児童・生徒に対する肥満度の測定指数として、以下のローレル指数が知られている。
# 体重が$w$[kg]で身長が$h$[m]である児童・生徒のローレル指数は以下で与えらえる。
# $$ \mathrm{Rohrerindex}=\frac{w}{h^3}\times 10~~~~~\text{肥満度}=\begin{cases}
#     ~~\text{低体重} ~~& \mathrm{Rohrerindex}<100 \\
#     ~~\text{標準} ~~& 100\leq \mathrm{Rohrerindex} <160 \\
#     ~~\text{肥満} ~~&  \mathrm{Rohrerindex}\geq 160
#   \end{cases}$$
# ある児童・生徒５名のデータを用いて、ローレル指数に基づき標準に分類される児童・生徒数及び標準である児童・生徒のローレル指数の最大値を出力プログラムを`ml1_02_02.py`として作成した。プログラムを完成させ、正しい出力結果を答えよ。

# %%
# ml1_02_02.py を実行する
# %run ml1_02_02.py

# %% [markdown]
# ## **問題３**
# 身長と体重、体脂肪のサンプルデータを`sample_data.csv`として出力するプログラムを`ml1_02_03.py`として作成した。出力されたデータのサンプル数を答えよ。

# %%
# ml1_02_03.py を実行する
# %run ml1_02_03.py
