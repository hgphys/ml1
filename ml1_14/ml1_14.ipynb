# %% [markdown]
# # **第１４回 分類（４）多クラス分類**

# %% [markdown]
# ## **問題１**
# ２次元入力３クラス分類のためのデータ`data/data.csv`に対してロジスティック回帰を行うプログラムを`ml1_14_01.py`として作成した。プログラムを完成させ、推定されたパラメータにおける平均交差エントロピー誤差の値を答えよ。ただし、学習率を0.05とし、小数点以下第３位までの数値で求めること。

# %%
# ml1_14_01.py を実行する
# %run ml1_14_01.py

# %% [markdown]
# ## **問題２**
# ２次元入力２クラス分類のためのデータ`data/data.csv`に対して、偶数行を訓練データ、奇数行をテストデータとしてロジスティック回帰を行うプログラムを`ml1_14_02.py`としてプログラムを作成した。混同行列を計算し、正解率を%表示で小数点以下第2位までの数値で求めること。

# %%
# ml1_14_02.py を実行する
# %run ml1_14_02.py
