# %% [markdown]
# # **第５回 機械学習のための数学（１）線形代数の基礎**

# %% [markdown]
# ## **問題１**
# 次の問題を解くプログラムを`ml1_05_01.py`として作成した。以下の連立方程式を解け。
# $$ \begin{cases}
#  x_1 + 2 x_2 +  x_3 = 3 \\
# 2 x_1 + 3 x_2 + 4 x_3 = 5 \\
# 3 x_1 + 4 x_2 + 5 x_3 = 7 \\
# \end{cases}$$

# %%
# ml1_05_01.py を実行する
# %run ml1_05_01.py

# %% [markdown]
# ## **問題２**
# `img/*.jpg`のRGBに分解された花の画像を読込みテンソルに変換、３つの画像を合成して元のRGB画像に戻しその画像を`img/rgb_image.jpg`として保存するプログラムを`ml1_05_02.py`として作成した。テンソルの(500,10)成分の値は何か。また、画像に写っている花は何色か答えよ。ただし、テンソルの添字は0から始まるものとする。

# %%
# ml1_05_02.py を実行する
# %run ml1_05_02.py

# %% [markdown]
# ## **問題３**
# 問題２で出力した`img/rgb_image.jpg`を読込み、グレースケールに変換した行列を特異値分解して、特異値が大きい順に対応する行列（画像）を出力、また、特異値の総和が全体の99.9%になるまで分解した画像を合成したものを出力するプログラムを`ml1_05_03.py`として作成した。このとき、特異値は全てで何個であり、大きい順から何個足すことで、99.9%の画像を復元することができているか答えよ。

# %%
# ml1_05_03.py を実行する
# %run ml1_05_03.py
